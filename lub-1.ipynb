# %%
import pandas as pd
import numpy as np
data  = pd.read_csv('fb_ads_president_scored_anon.csv')

# %%
data.shape
# Out:
# (246745, 40)

# %%
data.head()
# Out:
#                    page_id                        page_name  \
# 0  page_id_124974587580398         Texas Organizing Project
# 1  page_id_124974587580398         Texas Organizing Project
# 2  page_id_124974587580398         Texas Organizing Project
# 3  page_id_106769148511724  National Newsletter - NewsBreak
# 4  page_id_106769148511724  National Newsletter - NewsBreak
#
#                                                ad_id ad_creation_time  \
# 0  0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9...       2024-10-21
# 1  86229868e6bde3661724fe02da93504bb4fb5da8c2550d...       2024-10-18
# 2  07b5aefc27e872e971f793e49aac38496fa62e484f3928...       2024-10-13
# 3  c62978153c04116d88ead49379916855f2cb58bf788631...       2024-11-02
# 4  785e91ef18a5794565af03a6df4e7077fe1d915bfb3402...       2024-11-02
#
#   ad_delivery_start_time ad_delivery_stop_time                       bylines  \
# 0             2024-10-28            2024-11-06  Texas Organizing Project PAC
# ...
